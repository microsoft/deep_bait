# %% [markdown]
# # Batch AI
# In this notebook we will go through the steps of setting up the cluster executing the notebooks and pulling the executed notebooks locally.

# %% [markdown]
# We have defined a setup script called setup.py. Here we are simply executing it which will also bring all the varialbes and methods into the notebook namespace. You can also use the setup script inside an ipython environment simply execute anaconda-project run ipython-bait

# %%
from dotenv import load_dotenv # Including for now since other ways have bugs
load_dotenv(override=True)

# %%
WORKSPACE='workspace'
EXPERIMENT='multiframework'

# %%
# %run setup_bait.py

# %% [markdown]
# Below we setup the cluster and wait for the VMs to be allocated

# %%
create_workspace(WORKSPACE)

# %%
setup_cluster(WORKSPACE)

# %%
wait_for_cluster(WORKSPACE)
# Out:
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 0; Idle: 0; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: resizing Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 0; Unusable: 0; Running: 0; Preparing: 10; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 3; Unusable: 0; Running: 0; Preparing: 7; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 3; Unusable: 0; Running: 0; Preparing: 7; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 3; Unusable: 0; Running: 0; Preparing: 7; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 3; Unusable: 0; Running: 0; Preparing: 7; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 3; Unusable: 0; Running: 0; Preparing: 7; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 3; Unusable: 0; Running: 0; Preparing: 7; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 7; Unusable: 0; Running: 0; Preparing: 3; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 7; Unusable: 0; Running: 0; Preparing: 3; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 7; Unusable: 0; Running: 0; Preparing: 3; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 7; Unusable: 0; Running: 0; Preparing: 3; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 7; Unusable: 0; Running: 0; Preparing: 3; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 7; Unusable: 0; Running: 0; Preparing: 3; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 0; Running: 0; Preparing: 1; Leaving: 0
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 1; Running: 0; Preparing: 0; Leaving: 0

# %% [markdown]
# Below we print the status of the cluster. We can see many details of the cluster we created including its name and the docker images for the various DL frameworks.

# %%
print_cluster_list(WORKSPACE)
# Out:
# [{'allocation_state': 'steady',
#   'allocation_state_transition_time': '2018-08-22T09:19:23.612Z',
#   'creation_time': '2018-08-22T09:17:15.294Z',
#   'current_node_count': 10,
#   'id': '/subscriptions/10d0b7c6-9243-4713-91a9-2730375d3a1b/resourceGroups/dbdemorg/providers/Microsoft.BatchAI/workspaces/workspace/clusters/mync6',
#   'name': 'mync6',
#   'node_setup': {'mount_volumes': {'azure_file_shares': [{'account_name': 'dbdemostr',
#                                                           'azure_file_url': 'https://dbdemostr.file.core.windows.net/dbdemoshare',
#                                                           'credentials': {},
#                                                           'directory_mode': '0777',
#                                                           'file_mode': '0777',
#                                                           'relative_mount_path': 'azurefileshare'}]}},
#   'node_state_counts': {'idle_node_count': 9,
#                         'leaving_node_count': 0,
#                         'preparing_node_count': 0,
#                         'running_node_count': 0,
#                         'unusable_node_count': 1},
#   'provisioning_state': 'succeeded',
#   'provisioning_state_transition_time': '2018-08-22T09:17:27.874Z',
#   'scale_settings': {'manual': {'node_deallocation_option': 'requeue',
#                                 'target_node_count': 10}},
#   'type': 'Microsoft.BatchAI/workspaces/clusters',
#   'user_account_settings': {'admin_user_name': 'demoUser'},
#   'virtual_machine_configuration': {'image_reference': {'offer': 'UbuntuServer',
#                                                         'publisher': 'Canonical',
#                                                         'sku': '16.04-LTS',
#                                                         'version': '16.04.201708151'}},
#   'vm_priority': 'dedicated',
#   'vm_size': 'STANDARD_NC6'}]

# %% [markdown]
# We can submit all the of the jobs with the submit_all function. We also have a submit function for each of the DL frameworks if you wish to execute one seperately.

# %%
create_experiment(WORKSPACE, EXPERIMENT)

# %%
submit_all(WORKSPACE, EXPERIMENT, epochs=10)
# Out:
# INFO:__main__:Submitting job run_cntk
# INFO:__main__:Submitting job run_chainer
# INFO:__main__:Submitting job run_mxnet
# INFO:__main__:Submitting job run_keras_cntk
# INFO:__main__:Submitting job run_keras_tf
# INFO:__main__:Submitting job run_caffe2
# INFO:__main__:Submitting job run_pytorch
# INFO:__main__:Submitting job run_tf
# INFO:__main__:Submitting job run_gluon

# %% [markdown]
# We can periodically execute the command below to observe the status of the jobs. Under the current subscription we only have 2 nodes so 2 nodes will be executing in parallel. If the exit-code is anything other than 0 then there has been a problem with the job.

# %%
print_jobs_summary(WORKSPACE, EXPERIMENT)
# Out:
# run_cntk: status:succeeded | exit-code 0
# run_chainer: status:succeeded | exit-code 0
# run_mxnet: status:succeeded | exit-code 0
# run_keras_cntk: status:succeeded | exit-code 0
# run_keras_tf: status:succeeded | exit-code 0
# run_caffe2: status:succeeded | exit-code 0
# run_pytorch: status:succeeded | exit-code 0
# run_tf: status:succeeded | exit-code 0
# run_gluon: status:succeeded | exit-code 0

# %% [markdown]
# We can use the wait_for_job function to wait for the completion of the job. Once it is completed then the stdout is printed out. Let's take a look at the tf job. We can tell the name of the job from the output of the print_jobs_summary as well as the log messages when we submitted the job.

# %%
wait_for_job(WORKSPACE, EXPERIMENT,'run_tf')
# Out:
# Cluster state: steady Target: 10; Allocated: 10; Idle: 9; Unusable: 1; Running: 0; Preparing: 0; Leaving: 0
# Job state: succeeded ExitCode: 0
# Waiting for job output to become available...
# OS:  linux
# Python:  3.5.2 (default, Nov 23 2017, 16:37:01)
# [GCC 5.4.0 20160609]
# Numpy:  1.14.2
# Tensorflow:  1.8.0
# Preparing train set...
# Preparing test set...
# Done.
# (50000, 3, 32, 32) (10000, 3, 32, 32) (50000,) (10000,)
# float32 float32 int32 int32
# CPU times: user 872 ms, sys: 560 ms, total: 1.43 s
# Wall time: 17.9 s
# CPU times: user 148 ms, sys: 0 ns, total: 148 ms
# Wall time: 147 ms
# CPU times: user 504 ms, sys: 264 ms, total: 768 ms
# Wall time: 780 ms
# 0 Train accuracy: 0.46875
# 1 Train accuracy: 0.625
# 2 Train accuracy: 0.765625
# 3 Train accuracy: 0.6875
# 4 Train accuracy: 0.8125
# 5 Train accuracy: 0.765625
# 6 Train accuracy: 0.78125
# 7 Train accuracy: 0.8125
# 8 Train accuracy: 0.734375
# 9 Train accuracy: 0.859375
# Training took 167.268 sec.
# CPU times: user 7.09 s, sys: 912 ms, total: 8 s
# Wall time: 7.76 s
# Accuracy:  0.7830528846153846
# Job state: succeeded ExitCode: 0

# %% [markdown]
# Now lets download one of the notebooks we ran.

# %%
download_files(WORKSPACE, EXPERIMENT, 'run_tf', 'notebooks')
# Out:
# INFO:__main__:Downloading Tensorflow_run_tf.ipynb
# Downloading https://dbdemostr.file.core.windows.net/dbdemoshare/10d0b7c6-9243-4713-91a9-2730375d3a1b/dbdemorg/workspaces/workspace/experiments/multiframework/jobs/run_tf/30e4bbd8-1f22-40f7-a8f9-5a25deb6e9a7/outputs/notebooks/Tensorflow_run_tf.ipynb?sv=2016-05-31&sr=f&sig=0CaL6WOmxXRsS%2BsmATD5k21UGIIHfM3wHOxqv2Fp6uA%3D&se=2018-08-22T10%3A42%3A49Z&sp=rl ...Done
# All files Downloaded

# %% [markdown]
# Open the notebook and you can compare the output we printed out from the stdout of the job when we executed the command wait_for_job. We can see that the outputs in the cells are identical. You can download the other notebooks as well by simply supplying the name of the job.

# %% [markdown]
# Once all the jobs are complete we can delete them and delete the cluster.

# %%
delete_all_jobs(WORKSPACE, EXPERIMENT)

# %%
delete_cluster()

# %%
print_status()
# Out:
# Cluster state: steady Target: 10; Allocated: 10; Idle: 10; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0

# %% [markdown]
# These simple methods make it very convenient but may not be suitable for each use case. For more details check out the Batch AI documentation as well as the setup script.
